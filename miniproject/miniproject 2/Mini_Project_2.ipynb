# %%
import pandas as pd
import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
vaccine_data = pd.read_csv(r"D:\College\TE\SEM-2\Practical\DSBDA\MP2\covid_vaccine_statewise.csv")

# %%
vaccine_data.head(5)
# Out:
#    Updated On  State  Total Doses Administered  Sessions   Sites   \
# 0  16/01/2021  India                   48276.0    3455.0   2957.0
# 1  17/01/2021  India                   58604.0    8532.0   4954.0
# 2  18/01/2021  India                   99449.0   13611.0   6583.0
# 3  19/01/2021  India                  195525.0   17855.0   7951.0
# 4  20/01/2021  India                  251280.0   25472.0  10504.0
#
#    First Dose Administered  Second Dose Administered  \
# 0                  48276.0                       0.0
# 1                  58604.0                       0.0
# 2                  99449.0                       0.0
# 3                 195525.0                       0.0
# 4                 251280.0                       0.0
#
#    Male (Doses Administered)  Female (Doses Administered)  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# ...

# %%
vaccine_data.describe()
# Out:
#        Total Doses Administered      Sessions        Sites   \
# count              7.621000e+03  7.621000e+03   7621.000000
# mean               9.188171e+06  4.792358e+05   2282.872064
# std                3.746180e+07  1.911511e+06   7275.973730
# min                7.000000e+00  0.000000e+00      0.000000
# 25%                1.356570e+05  6.004000e+03     69.000000
# 50%                8.182020e+05  4.547000e+04    597.000000
# 75%                6.625243e+06  3.428690e+05   1708.000000
# max                5.132284e+08  3.501031e+07  73933.000000
#
#        First Dose Administered  Second Dose Administered  \
# count             7.621000e+03              7.621000e+03
# mean              7.414415e+06              1.773755e+06
# std               2.995209e+07              7.570382e+06
# min               7.000000e+00              0.000000e+00
# 25%               1.166320e+05              1.283100e+04
# 50%               6.614590e+05              1.388180e+05
# ...

# %%
dose1 = vaccine_data.groupby("State")[["First Dose Administered"]].max()
dose1
# Out:
#                                           First Dose Administered
# State
# Andaman and Nicobar Islands                              216046.0
# Andhra Pradesh                                         17628583.0
# Arunachal Pradesh                                        692475.0
# Assam                                                  10495293.0
# Bihar                                                  23350171.0
# Chandigarh                                               700285.0
# Chhattisgarh                                            9181482.0
# Dadra and Nagar Haveli and Daman and Diu                 584370.0
# Delhi                                                   7835546.0
# Goa                                                     1094392.0
# Gujarat                                                28101222.0
# Haryana                                                10086831.0
# Himachal Pradesh                                        4249849.0
# ...

# %%
dose2 = vaccine_data.groupby("State")[["Second Dose Administered"]].max()
dose2
# Out:
#                                           Second Dose Administered
# State
# Andaman and Nicobar Islands                                94597.0
# Andhra Pradesh                                           6214312.0
# Arunachal Pradesh                                         186619.0
# Assam                                                    2208577.0
# Bihar                                                    4484768.0
# Chandigarh                                                223534.0
# Chhattisgarh                                             2587695.0
# Dadra and Nagar Haveli and Daman and Diu                   80851.0
# Delhi                                                    3000536.0
# Goa                                                       302519.0
# Gujarat                                                  9051153.0
# Haryana                                                  2923550.0
# Himachal Pradesh                                         1382592.0
# ...

# %%
male = vaccine_data.groupby("State")[["Male(Individuals Vaccinated)"]].max()
male
# Out:
#                                           Male(Individuals Vaccinated)
# State
# Andaman and Nicobar Islands                                        NaN
# Andhra Pradesh                                                     NaN
# Arunachal Pradesh                                                  NaN
# Assam                                                              NaN
# Bihar                                                              NaN
# Chandigarh                                                         NaN
# Chhattisgarh                                                       NaN
# Dadra and Nagar Haveli and Daman and Diu                           NaN
# Delhi                                                              NaN
# Goa                                                                NaN
# Gujarat                                                            NaN
# Haryana                                                            NaN
# ...

# %%
female = vaccine_data.groupby("State")[["Female(Individuals Vaccinated)"]].max()
female
# Out:
#                                           Female(Individuals Vaccinated)
# State
# Andaman and Nicobar Islands                                          NaN
# Andhra Pradesh                                                       NaN
# Arunachal Pradesh                                                    NaN
# Assam                                                                NaN
# Bihar                                                                NaN
# Chandigarh                                                           NaN
# Chhattisgarh                                                         NaN
# Dadra and Nagar Haveli and Daman and Diu                             NaN
# Delhi                                                                NaN
# Goa                                                                  NaN
# Gujarat                                                              NaN
# Haryana                                                              NaN
# ...

# %%
trans = vaccine_data.groupby("State")[["Transgender(Individuals Vaccinated)"]].max()
trans
# Out:
#                                           Transgender(Individuals Vaccinated)
# State
# Andaman and Nicobar Islands                                               NaN
# Andhra Pradesh                                                            NaN
# Arunachal Pradesh                                                         NaN
# Assam                                                                     NaN
# Bihar                                                                     NaN
# Chandigarh                                                                NaN
# Chhattisgarh                                                              NaN
# Dadra and Nagar Haveli and Daman and Diu                                  NaN
# Delhi                                                                     NaN
# Goa                                                                       NaN
# Gujarat                                                                   NaN
# ...
